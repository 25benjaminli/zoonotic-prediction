# %%
import pandas as pd

# %%
df = pd.read_table('raw_db.tsv', sep='\t')
print(df.head())
# Out:
#    virus tax id                                    virus name  \
# 0        438782                        Abaca bunchy top virus
# 1       1241371         Abalone herpesvirus Victoria/AUS/2009
# 2        491893  Abalone shriveling syndrome-associated virus
# 3         11788                 Abelson murine leukemia virus
# 4       2025595                                  Abisko virus
#
#                                        virus lineage  \
# 0  Viruses; Monodnaviria; Shotokuvirae; Cressdnav...
# 1  Viruses; Duplodnaviria; Heunggongvirae; Peplov...
# 2  Viruses; Duplodnaviria; Heunggongvirae; Urovir...
# 3  Viruses; Riboviria; Pararnavirae; Artvervirico...
# 4         Viruses; Riboviria; unclassified Riboviria
#
#                                            refseq id KEGG GENOME KEGG DISEASE  \
# 0  NC_010314, NC_010315, NC_010316, NC_010317, NC...         NaN          NaN
# 1                                          NC_018874         NaN          NaN
# ...

# %%
l = df[df['host name']=='Homo sapiens']['refseq id']
print(len(l))
# Out:
# 1398

# %%
for x in l:
    # for i in x:
    li = x.split(', ')
    for i in li:
        print(f"\"{i}\" [All Fields] OR ", sep='')
# Out:
# "NC_001729" [All Fields] OR
# "NC_001829" [All Fields] OR
# "AF028704" [All Fields] OR
# "NC_001401" [All Fields] OR
# "AF028705" [All Fields] OR
# "NC_006152" [All Fields] OR
# "NC_007548" [All Fields] OR
# "NC_007549" [All Fields] OR
# "NC_007550" [All Fields] OR
# "NC_007551" [All Fields] OR
# "NC_007552" [All Fields] OR
# "NC_007553" [All Fields] OR
# "NC_007554" [All Fields] OR
# "NC_007555" [All Fields] OR
# "NC_007556" [All Fields] OR
# "NC_007557" [All Fields] OR
# "NC_007558" [All Fields] OR
# "NC_010820" [All Fields] OR
# "NC_001918" [All Fields] OR
# "NC_004421" [All Fields] OR
# "NC_055230" [All Fields] OR
# "NC_055330" [All Fields] OR
# "NC_055331" [All Fields] OR
# "NC_055332" [All Fields] OR
# "JN860200" [All Fields] OR
# "NC_025391" [All Fields] OR
# "NC_001694" [All Fields] OR
# "NC_001352" [All Fields] OR
# "NC_001357" [All Fields] OR
# "NC_055508" [All Fields] OR
# "AF411814" [All Fields] OR
# "KJ956407" [All Fields] OR
# "NC_005080" [All Fields] OR
# ...
